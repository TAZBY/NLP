# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag.stanford import StanfordPOSTagger
root_path="/home/tazby/Documents/tagger/"
pos_tagg = StanfordPOSTagger(root_path + "models/french.tagger", root_path + "stanford-postagger.jar",encoding='utf8') #instance de la classe StanfordPOSTagger en UTF-8


file = open("regles.txt")
lines = file.readlines()

file.close()

mot="jardine"

motokenizze = word_tokenize(mot)
mottagg = pos_tagg.tag(motokenizze)

print(mottagg)
tag=""

for va in mottagg:
    tag=va[1]
    
suffixe = mot[-2]+mot[-1]
nvlt = ""

prempartie=""
chainef = ""

for line in lines:
    line = line.strip()
    line = line.replace("*","")
    if len(line) != 0:
        lin = word_tokenize(line)
    
        for ligne in lin:
            nvlt = ligne
        if(tag == 'V' or tag == 'VINF'):
            
            if(suffixe == lin[0]):
                mss = mot.replace(suffixe, nvlt)
                print(mot+" -> "+mss)
# Out:
# [('jardine', 'NC')]

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag.stanford import StanfordPOSTagger
root_path="nltkTools/"
pos_tagg = StanfordPOSTagger(root_path + "french.tagger", root_path + "stanford-postagger.jar",encoding='utf8') #instance de la classe StanfordPOSTagger en UTF-8


file = open("regles.txt")
lines = file.readlines()

file.close()

mot=str(input("Veuillez entrer un mot svp:"))

motokenizze = word_tokenize(mot)
mottagg = pos_tagg.tag(motokenizze)

#print(mottagg)
tag=""

for va in mottagg:
    tag=va[1]

#Pour les verbes
suffixe = mot[-2]+mot[-1]
nvlt = ""
typemot = ""
if(tag == 'V' or tag == 'VINF'):
    typemot = "un Verbe"
if(tag =='NC'):
    typemot = "un Nom Commun"
if(tag =='ADJ'):
    typemot = "un Adjectif"
if(tag =='DET'):
    typemot = "un Déterminant"
if(tag =='P'):
    typemot = "une Préposition"

print("Le mot que vous avez entré est : "+typemot)

prempartie=""
chainef = ""

for line in lines:
    line = line.strip()
    line = line.replace("*","")
    if len(line) != 0:
        lin = word_tokenize(line)
    
        for ligne in lin:
            nvlt = ligne
        if(tag == 'V' or tag == 'VINF'):
            if(len(lin[0])>2):
                if(lin[0] in mot):
                    mss = mot.replace(lin[0], nvlt)
                    print(mot+" -> "+mss)
                
            if(suffixe == lin[0]):
                mss = mot.replace(suffixe, nvlt)
                print(mot+" -> "+mss)
        elif(tag == 'ADJ'):
            if(lin[0] in mot):
                mss = mot.replace(lin[0], nvlt)
                print(mot+" -> "+mss)
        elif(tag == 'NC'):
            if(lin[0] in mot):
                mss = mot.replace(lin[0], nvlt)
                print(mot+" -> "+mss)
        elif(tag == 'ADV'):
            if(lin[0] in mot):
                mss = mot.replace(lin[0], nvlt)
                print(mot+" -> "+mss)
        elif(tag == 'DET'):
            if(lin[0] in mot):
                mss = mot.replace(lin[0], nvlt)
                print(mot+" -> "+mss)
        elif(tag == 'P'):
            if(lin[0] in mot):
                mss = mot.replace(lin[0], nvlt)
                print(mot+" -> "+mss)
# Out:
# Veuillez entrer un mot svp:jardiner
# Le mot que vous avez entré est : un Verbe
# jardiner -> jardine
# jardiner -> jardinière
# jardiner -> jardineant
# jardiner -> jardinage
# jardiner -> jardinerie
# jardiner -> jardineuse
# jardiner -> jardingeoire
# jardiner -> jardineoire
# jardiner -> jardineoir
# jardiner -> jardinant
# jardiner -> jardinette
# jardiner -> jardinable
# jardiner -> jardinement
# jardiner -> jardination
# jardiner -> jardineur
# jardiner -> jardinaison
# jardiner -> jardincation
# jardiner -> jardinnaison
# jardiner -> jardinsation
# jardiner -> jardinquage
# jardiner -> jardineraie
# jardiner -> jardinaille
# jardiner -> jardinage
# jardiner -> jardination
# jardiner -> jardinage
# jardiner -> jardination
# jardiner -> jardinationnisme
# jardiner -> jardination
# jardiner -> jardinable

# %%
file = open("jdmregles.txt")
lines = file.readlines()
file.close()
display(lines)
# Out:
# ['\n',
#  'Master 1 informatique - Montpellier\n',
#  'HMIN230-Traitement automatique de la langue naturelle\n',
#  '\n',
#  '\n',
#  ' Schémas de transformations morphologiques\n',
#  '\n',
#  'Modèle :\n',
#  'X ==>  Y    //   “commentaire + exemple  ==>  contraintes sémantiques sur X et/ou Y\n',
#  '(à compléter)\n',
#  '(attention certaines règles ci-dessous oint un format non standard)\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '*er ==>  *age // laver ⇒ lavage\n',
#  '*er ==>  *ement // laver ==>  lavement\n',
#  '\n',
#  '\n',
#  '*er => *eur’  ==>  “verbe vers agent” (exemple : miner => mineur)  ==>  Y r_isA personne\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  ' *er ==>  *euse’ \t//  “verbe vers agent” (exemple : chanter => chanteuse) r_isa Personne\n',
#  ' *ger ==>  *geoire’\t\t //  “verbe vers lieu” (exemple : manger => mangeoire)\n',
#  ' *er ==>  *oire’ //  “verbe vers lieu” // (exemple : patiner => patinoire) r_lieu\n',
#  ' *er ==>  *oir’ \t//  “verbe vers lieu” // (exemple : egoutter => egouttoir)\n',
#  ' *er ==>  *age’  //   “verbe vers nom d’action” // (exemple : bavarder => bavardage)\n',
#  '\n',
#  '*er & pos == V ==> *e  & pos = N\n',
#  '*er & pos == V  ==>  *ant & pos = ADJ\n',
#  '*ner & pos == V ==> *nier & pos = N\n',
#  '*er  & pos == V ==> *ette & pos = N\n',
#  '\n',
#  '\n',
#  ' *uire ==>  *ction’  //  “verbe vers nom” (exemple : induire => induction)\n',
#  ' *uire ==>  *cteur’  // “verbe vers agent” (exemple : conduire => conducteur)\n',
#  ' *uire ==>  *ctrice’ //   “verbe vers agent” (exemple : conduire => conductrice)\n',
#  'Verbe:ister ==> nom:istance\n',
#  'verbe:er ==> nom:able\n',
#  ' *ger ==>  *gement’  //   “verbe vers nom” (exemple : déranger => dérangement)\n',
#  'verbe:ger ==> nom:geur\n',
#  'verbe:ner ==> nom:naison\n',
#  'verbe:quer ==> nom:cation\n',
#  'verbe:ner ==> nom:naison\n',
#  'verbe:ser ==> nom:sation\n',
#  'verbe:quer ==> nom:quage\n',
#  'Verbe:ter:nom:tement\n',
#  'Verbe:dir ==> nom:d\n',
#  'Verbe:lir ==> nom:lissage\n',
#  'verbe:er ==> nom:ant\n',
#  'verbe:ller ==> nom:l\n',
#  'Verbe:uer ==> nom:cation\n',
#  'Nom:” “ ==> adj:able\n',
#  'Verbe:”er” ==> adj:ible\n',
#  'Nom:” “ ==> Nom:”age”\n',
#  'Nom:”ier” ==> Nom:”eraie”\n',
#  'Verbe:”er” ==> Nom:”ail”\n',
#  'Verbe:”er ==> Nom:”aille”\n',
#  'adj:””:adv:”ante”\n',
#  'Nom:” “ ==> nom:”aison”\n',
#  'Nompropre:” “ ==> nom:”oise”\n',
#  'Verbe:” “ ==> nom:”ateur”\n',
#  'Verbe:”er” ==> nom:”ation”\n',
#  'Nom:” “ ==> nom:”isme”\n',
#  'Nom:” “ ==> nom:”iste”\n',
#  'Nom:” “ ==> verbe:”ir”\n',
#  'Verbe:” “ ==> nom:”iteur” \n',
#  '\n',
#  '\n',
#  '\n',
#  'nom:eur ==> nom:euse\n',
#  'nom:er ==> nom:ance\n',
#  'nom:" " ==> nom:aire\n',
#  'nom:" " ==> nom:iaire\n',
#  'nom:" " ==> nom:ale\n',
#  'nom:" " ==> nom:al\n',
#  'nom:" " ==> adj:al\n',
#  'nom:"ale" ==> nom:ales\n',
#  'nom:"al", nom:aux\n',
#  'nom:" " ==> adj:ale\n',
#  'nom: " " ==> adj:elle\n',
#  'nom" " ==> adj:acé  \n',
#  'nom:""  ==> adj:an\n',
#  'nom:""  ==> adj:ane\n',
#  '\n',
#  '    \n',
#  'Adj:ant:adv:amment r_manner\n',
#  'adj:ante ==> adv:amment\n',
#  'adj:tif:nom:tivité\n',
#  'adv:ant:nom:ance\n',
#  'adv:ante:nom:ance\n',
#  'nom:"":adj:ain\n',
#  'nom:"":adj:aine\n',
#  'nom:""nom"ard"\n',
#  'nom:"" ==> :nom"arde"\n',
#  '\n',
#  '\n',
#  '\n',
#  'fPOS de JDM (lié au term avec une relation POS  id=4)\n',
#  '\n',
#  '\n',
#  'Abr:\n',
#  'Adj:\n',
#  'Adj:Card\n',
#  'Adj:Fem+InvPL\n',
#  'Adj:Fem+PL\n',
#  'Adj:Fem+SG\n',
#  'Adj:Fem+SG:InvGen+PL\n',
#  'Adj:Indef\n',
#  'Adj:InvGen+InvPL\n',
#  'Adj:InvGen+PL\n',
#  'Adj:InvGen+SG\n',
#  'Adj:InvGen+SG:InvGen+PL\n',
#  'Adj:Mas+InvPL\n',
#  'Adj:Mas+PL\n',
#  'Adj:Mas+SG\n',
#  'Adj:Ord\n',
#  'Adj:Pos\n',
#  'Adv:\n',
#  'Analogy:\n',
#  'Card:\n',
#  'Chunk:\n',
#  'Con:\n',
#  'Concept:\n',
#  'Conj:\n',
#  'Conj:Coord\n',
#  'Conj:Sub\n',
#  'Date:\n',
#  'Det:\n',
#  'Det:Fem+PL\n',
#  'Det:Fem+SG\n',
#  'Det:InvGen+PL\n',
#  'Det:InvGen+SG\n',
#  'Det:InvGen+SG:InvGen+PL\n',
#  'Det:Mas+PL\n',
#  'Det:Mas+SG\n',
#  'Expression:\n',
#  'Fem+SG+DemPro+Prox\n',
#  'Formule:\n',
#  'Gender:Fem\n',
#  'Gender:Inv\n',
#  'Gender:Mas\n',
#  'Info:\n',
#  'Int:\n',
#  'InvGen+PL+P1+PProRefl\n',
#  'Link:\n',
#  'Mas+SG+DemPro+Prox\n',
#  'Mas+SGDemPro2\n',
#  'Modifier:\n',
#  'Modifier:Nom\n',
#  'Modifier:Ver\n',
#  'NNom+Fem+SG+P3+PProRefl\n',
#  'NNom+InvGen+SG+P1+PProRefl\n',
#  'NNom+InvGen+SG+P3+PProRefl\n',
#  'NNom+Mas+SG+P3+PProRefl\n',
#  'Nom+InvGen+SG+P3+PC\n',
#  'Nom:\n',
#  'Nom:Fem+InvPL\n',
#  'Nom:Fem+PL\n',
#  'Nom:Fem+SG\n',
#  'Nom:Fem+SG+Nom\n',
#  'Nom:InvGen+InvPL\n',
#  'Nom:InvGen+PL\n',
#  'Nom:InvGen+SG\n',
#  'Nom:InvGen+SG:InvGen+PL\n',
#  'Nom:Mas+InvPL\n',
#  'Nom:Mas+PL\n',
#  'Nom:Mas+SG\n',
#  'Nom:Mas+SG+Nom\n',
#  'Nom:SG\n',
#  'Nom:SG+Card\n',
#  'Number:Inv\n',
#  'Number:Plur\n',
#  'Number:Sing\n',
#  'Ono:\n',
#  'POS:\n',
#  'Pre:\n',
#  'Prefix:\n',
#  'Pro:\n',
#  'Pro:3Fem+PL\n',
#  'Pro:3Fem+SG\n',
#  'Pro:3Mas+PL\n',
#  'Pro:3Mas+SG\n',
#  'Pro:Dem\n',
#  'Pro:Fem+PL\n',
#  'Pro:Fem+SG\n',
#  'Pro:Indef\n',
#  'Pro:Interro\n',
#  'Pro:InvGen+PL\n',
#  'Pro:InvGen+SG\n',
#  'Pro:Mas+PL\n',
#  'Pro:Mas+SG\n',
#  'Pro:PL+P1\n',
#  'Pro:PL+P2\n',
#  'Pro:PL+P3\n',
#  'Pro:Pers\n',
#  'Pro:Pers:COD\n',
#  'Pro:Pers:COI\n',
#  'Pro:Pers:SUJ\n',
#  'Pro:Pos\n',
#  'Pro:Rel\n',
#  'Pro:SG+P1\n',
#  'Pro:SG+P2\n',
#  'Pro:SG+P3\n',
#  'Pro:SG+P3:PL+P3\n',
#  'Pro:SG+P3PL+P3\n',
#  'Punct:\n',
#  'QPro:\n',
#  'Relation:\n',
#  'Suffix:\n',
#  'Symbole:\n',
#  'Tournure:\n',
#  'Tournure:Impersonnelle\n',
#  'Ukn:\n',
#  'Ver:\n',
#  'Ver:CPre+PL+P1\n',
#  'Ver:CPre+PL+P2\n',
#  'Ver:CPre+PL+P3\n',
#  'Ver:CPre+SG+P1:CPre+SG+P2\n',
#  'Ver:CPre+SG+P3\n',
#  'Ver:Conjug\n',
#  'Ver:IFut+PL+P1\n',
#  'Ver:IFut+PL+P2\n',
#  'Ver:IFut+PL+P3\n',
#  'Ver:IFut+SG+P1\n',
#  'Ver:IFut+SG+P2\n',
#  'Ver:IFut+SG+P3\n',
#  'Ver:IImp+PL+P1\n',
#  'Ver:IImp+PL+P1:SPre+PL+P1\n',
#  'Ver:IImp+PL+P1:SPre+PL+P1:SImp+PL+P1\n',
#  'Ver:IImp+PL+P2:SPre+PL+P2\n',
#  'Ver:IImp+PL+P2:SPre+PL+P2:SImp+PL+P2\n',
#  'Ver:IImp+PL+P3\n',
#  'Ver:IImp+SG+P1:IImp+SG+P2\n',
#  'Ver:IImp+SG+P3\n',
#  'Ver:IPSim+PL+P1\n',
#  'Ver:IPSim+PL+P2\n',
#  'Ver:IPSim+PL+P3\n',
#  'Ver:IPSim+SG+P1\n',
#  'Ver:IPSim+SG+P1:IPSim+SG+P2\n',
#  'Ver:IPSim+SG+P2\n',
#  'Ver:IPSim+SG+P3\n',
#  'Ver:IPre+PL+P1\n',
#  'Ver:IPre+PL+P1:ImPre+PL+P1\n',
#  'Ver:IPre+PL+P2\n',
#  'Ver:IPre+PL+P2:ImPre+PL+P2\n',
#  'Ver:IPre+PL+P3\n',
#  'Ver:IPre+PL+P3:SPre+PL+P3\n',
#  'Ver:IPre+PL+P3:SPre+PL+P3:SImp+PL+P3\n',
#  'Ver:IPre+SG+P1\n',
#  'Ver:IPre+SG+P1:IPre+SG+P2\n',
#  'Ver:IPre+SG+P1:IPre+SG+P2:IPSim+SG+P1:IPSim+SG+P2:ImPre+SG+P2\n',
#  'Ver:IPre+SG+P1:IPre+SG+P2:ImPre+SG+P2\n',
#  'Ver:IPre+SG+P1:IPre+SG+P3:SPre+SG+P1:SPre+SG+P3:ImPre+SG+P2\n',
#  'Ver:IPre+SG+P2\n',
#  'Ver:IPre+SG+P2:SPre+SG+P2\n',
#  'Ver:IPre+SG+P3\n',
#  'Ver:IPre+SG+P3:IPSim+SG+P3\n',
#  'Ver:IPre+SG+P3:ImPre+SG+P2\n',
#  'Ver:IPre+SG+P3:SPre+SG+P3\n',
#  'Ver:Imp+PL+P1\n',
#  'Ver:Imp+PL+P2\n',
#  'Ver:Imp+SG+P2\n',
#  'Ver:Inf\n',
#  'Ver:Inf+:IPre+SG+P1:IPre+SG+P3:SPre+SG+P1:SPre+SG+P3:ImPre+SG+P2\n',
#  'Ver:PPas\n',
#  'Ver:PPas+Fem+PL\n',
#  'Ver:PPas+Fem+PL:IPre+PL+P2:ImPre+PL+P2\n',
#  'Ver:PPas+Fem+SG\n',
#  'Ver:PPas+Fem+SG:SPre+SG+P1:SPre+SG+P3\n',
#  'Ver:PPas+Mas+PL\n',
#  'Ver:PPas+Mas+PL:IPSim+SG+P1:IPSim+SG+P2\n',
#  'Ver:PPas+Mas+PL:IPre+SG+P1:IPre+SG+P2:IPSim+SG+P1:IPSim+SG+P2:ImPre+SG+P2\n',
#  'Ver:PPas+Mas+SG\n',
#  'Ver:PPas+Mas+SG:IPSim+SG+P1:IPSim+SG+P2\n',
#  'Ver:PPas+Mas+SG:IPre+SG+P3\n',
#  'Ver:PPas+Mas+SG:PPas+Mas+PL\n',
#  'Ver:PPas+Mas+SG:PPas+Mas+PL:IPSim+SG+P1:IPSim+SG+P2\n',
#  'Ver:PPas+Mas+SG:PPas+Mas+PL:IPre+SG+P1:IPre+SG+P2:ImPre+SG+P2\n',
#  'Ver:PPre\n',
#  'Ver:PPre+Fem+SG\n',
#  'Ver:PPre+Mas+SG\n',
#  'Ver:SImp+PL+P1\n',
#  'Ver:SImp+PL+P2\n',
#  'Ver:SImp+PL+P3\n',
#  'Ver:SImp+SG+P1\n',
#  'Ver:SImp+SG+P2\n',
#  'Ver:SImp+SG+P3\n',
#  'Ver:SPre+PL+P3\n',
#  'Ver:SPre+SG+P1\n',
#  'Ver:SPre+SG+P1:ImPre+SG+P2\n',
#  'Ver:SPre+SG+P1:SPre+SG+P3\n',
#  'Ver:SPre+SG+P1:SPre+SG+P3:SImp+SG+P1\n',
#  'Ver:SPre+SG+P2\n',
#  'Ver:SPre+SG+P2:SImp+SG+P2\n',
#  'Ver:SPre+SG+P3\n',
#  'VerbalMode:Conditionnel\n',
#  'VerbalMode:Indicatif\n',
#  'VerbalMode:Subjonctif\n',
#  'VerbalTime:Future\n',
#  'VerbalTime:Past\n',
#  'VerbalTime:Present\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n']
